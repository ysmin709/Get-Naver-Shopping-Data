# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import bs4
import pandas as pd
import numpy as np

# %%
keyword = '바질'
driver = webdriver.Chrome(r'C:\Users\YSM\Downloads\chromedriver_win32\chromedriver.exe')
driver.get('https://search.shopping.naver.com/search/all?query={}&cat_id=&frm=NVSHATC'.format(keyword))

# %%
time.sleep(3)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(1)

item_source = bs4.BeautifulSoup(driver.page_source, 'lxml')
item_list = item_source.select('div.basicList_info_area__17Xyo')

# %%
title_list = []
price_list = []
review_list = []
buy_list = []

for item in item_list:
    title = item.select_one('a').text.replace('\n', '')
    price = item.select_one('span.price_num__2WUXn').text
    ReviewAndBuy = item.select('a.basicList_etc__2uAYO > em')
    try:
        review = ReviewAndBuy[0].text + '개'
    except IndexError:
        review = '없음'
    
    try:
        buy = ReviewAndBuy[1].text + '개'
    except IndexError:
        buy = '없음'
        
    title_list.append(title)
    price_list.append(price)
    review_list.append(review)
    buy_list.append(buy)
#print(review_list)
#print(title_list, price_list, review_list, buy_list)
df = pd.DataFrame({'상품명':title_list, '가격':price_list, '리뷰수':review_list, '구매건수':buy_list})
df
# Out:
#                                                   상품명       가격      리뷰수  \
# 0                             허브 화분 로즈마리 바질트리 바질 애플민트   9,900원     149개
# 1                             잉글리쉬라벤더 박하 스위트바질 모종 키우기   1,000원  12,890개
# 2                     도시농장 생 바질 100g 농업회사법인 그린(Griin)   6,000원     582개
# 3                           이딸페페 바질 건조허브 파스타 피자 바질페스토   3,500원      39개
# 4           허브키우기 허브 화분 모종 바질 루꼴라 로즈마리 라벤더 애플민트 스위트바질   1,000원  12,890개
# 5   애플민트 로즈마리 스피아 페퍼 초코 스위트바질 장미 라벤더 워터코인 레몬밤 구문초 ...   1,000원  10,749개
# 6              허브모음 바질트리 로즈마리 페파민트 라벤더 민트 식용허브 공기정화식물   2,000원   2,348개
# 7                    허브키우기 식용 허브 화분 모종 바질 로즈마리 라벤더 민트   1,000원  12,886개
# 8   허브화분 바질 루꼴라 고수 애플민트 스피아민트 라벤더 레몬밤 장미허브 초코민트 로즈...     990원     827개
# 9                              바질 생바질 스윗바질 가락시장(100g)   6,000원     103개
# 10                             바질 생바질 스윗바질 가락시장 (1KG)  39,000원     261개
# 11  허브 화분 로즈마리 외목대 페퍼민트 바질트리 구문초 레몬밤 애플민트 바질 장미허브 ...   9,900원     149개
# 12    허브 모음 로즈마리 애플 페퍼 민트 마리노 라벤더 바질 스피아 월동 화분 모종 키우기   2,200원     185개
# 13                                     바질트리 허브식물 식용식물  14,000원      55개
# 14                               바질화분 (만원이상 배송 가능합니다)   7,000원      20개
# 15         향기나는 허브식물 모음 (유칼립투스 애플민트 라벤더 바질트리 로즈마리 율마)   9,900원     418개
# 16                            식용바질 허브 식물 50g 100g 생바질   4,900원      18개
# 17          로즈마리 애플민트 바질 페퍼민트 바질트리 초코민트 토분 허브 화분 허브모음   8,900원      77개
# 18                              몸에 좋은 허브 스위트 바질 모종 화분   9,900원     240개
# 19                    도시농장 생 바질 100g 농업회사법인 그린(Griin)   6,000원     582개
# 20                      허브 키우기 스위트바질 레몬타임 파인애플민트 로즈마리   3,000원       3개
# 21            허브 공기정화 다육 식물 소품 미니 화분 바질 로즈마리 루꼴라 스테비아   1,600원   3,282개
# 22         율마 로즈마리 페퍼 초코 바질 장미 애플민트 레몬밤 구문초 라벤더 허브 식물     950원       1개
# 23  허브 화분 독일 토분 로즈마리 모히또 페퍼민트 바질트리 구문초 레몬밤 애플민트 스위...  15,900원       6개
# 24  허브 화분 독일 토분 로즈마리 모히또 페퍼민트 바질트리 구문초 레몬밤 애플민트 스위...  15,900원       6개
# 25                           유럽향신료 모음 후추 페페로치노 바질 파슬리   3,000원       없음
# 26                 바질트리 향이 좋은 바질트리 허브 소품 중품 이태리토분 바구니   5,000원       없음
# 27                              몸에 좋은 허브 스위트 바질 모종 화분   9,900원       없음
# 28              갑조네 허브 향기나는식물 로즈마리 레몬밤 바질 허브화분 공기정화식물   2,000원   1,634개
# 29                                    허브 모종 바질화분 식용허브   4,100원       6개
# 30                                    스윗바질 1봉 100g 생잎   7,000원   3,189개
# 31                                     바질화분2개.루꼴라화분2개  18,000원      82개
# 32             플라워무드 허브키우기 로즈마리 스위트바질 페퍼민트 레몬밤 토분 SET  19,000원      13개
# 33                    채소랑 바질 100g,생바질, 얼지않고 정말 신선한 바질   7,500원     187개
# 34        [네오플라워] 허브  낱개 판매 / 애플민트 바질 레몬밤 로즈마리 라벤더 바질   1,220원   6,692개
# 35                                     바질 100g / 200g   4,000원      20개
# 36                                      바질 생잎 1kg 패스토  60,000원      11개
# 37                 바질트리 향이 좋은 바질트리 허브 소품 중품 이태리토분 바구니   5,000원       1개
# 38             허브 화분 모종 바질 레몬밤 페퍼민트 스피아민트 구문초 율마 스테비아   2,000원       8개
# 39                      허브 생잎 16종 20g 로즈마리 애플민트 타임 바질  10,050원     199개
# 40                                   허브 바질 다양한허브 애플민트   2,120원       3개
# 41    식용허브모음 바질 로즈마리 애플민트 화분 페퍼민트 라벤더 유칼립투스 율마 허브 키우기  11,700원      33개
# 42        로즈마리 바질 애플민트 스피아민트 박하 초코민트 라벤더 허브 키우기 좋은 식물  14,900원       9개
# 43                         바질트리 식용식물 독일 토분 허브키우기 허브화분  19,900원       3개
# 44                                바질트리 바질 허브모종 공기정화식물   8,200원       3개
# 45             허브식물 모음 레몬밤 로즈마리 스위트바질 스피아민트 애플민트 페퍼민트   2,000원       8개
# 46                       허브 식물 공기정화식물 다육 미니 화분 키우기 바질   1,600원   3,883개
# 47                                  휘스트리 허브바질트리 화분 셋트  17,600원       3개
#
#        구매건수
# 0      405개
# 1   10,331개
# 2      229개
# 3       34개
# 4   10,331개
# 5    6,424개
# 6    3,037개
# 7   10,410개
# 8    1,157개
# 9      431개
# 10     498개
# 11     405개
# 12     254개
# 13      17개
# 14      56개
# 15     594개
# 16     100개
# 17     247개
# 18      70개
# 19     229개
# 20       9개
# 21     505개
# 22       없음
# 23      19개
# 24      19개
# 25       없음
# 26       없음
# 27       없음
# 28       없음
# 29       없음
# 30   3,359개
# 31     177개
# 32       없음
# 33     568개
# 34       없음
# 35       없음
# 36       5개
# 37       5개
# 38       없음
# 39     208개
# 40       없음
# 41      59개
# 42      31개
# 43       6개
# 44      11개
# 45       없음
# 46       없음
# 47       9개

# %%
ext = df.상품명.str.extract('(\d+g|\d+kg|\d+KG)')
    
for i in range(len(ext)):
    if 'kg' in str(ext[0][i]):
        temp = ext[0][i].split('kg')
        ext[0][i] = int(temp[0]) * 1000
    elif 'Kg' in str(ext[0][i]):
        temp = ext[0][i].split('Kg')
        ext[0][i] = int(temp[0]) * 1000
    elif 'KG' in str(ext[0][i]):
        temp = ext[0][i].split('KG')
        ext[0][i] = int(temp[0]) * 1000
    elif 'g' in str(ext[0][i]):
        temp = ext[0][i].split('g')
        ext[0][i] = int(temp[0])

# %%
price = df.가격
for i in range(len(price)):
    if ',' in price[i]:
        b = price[i].split(',')
        c = b[1].split('원')
        d = b[0] + c[0]
        df['가격'][i] = int(d)
    else:
        c = price[i].split('원')
        df['가격'][i] = int(c[0])
df
# Out:
#                                                   상품명     가격      리뷰수     구매건수
# 0                             허브 화분 로즈마리 바질트리 바질 애플민트   9900     149개     405개
# 1                             잉글리쉬라벤더 박하 스위트바질 모종 키우기   1000  12,890개  10,331개
# 2                     도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000     582개     229개
# 3                           이딸페페 바질 건조허브 파스타 피자 바질페스토   3500      39개      34개
# 4           허브키우기 허브 화분 모종 바질 루꼴라 로즈마리 라벤더 애플민트 스위트바질   1000  12,890개  10,331개
# 5   애플민트 로즈마리 스피아 페퍼 초코 스위트바질 장미 라벤더 워터코인 레몬밤 구문초 ...   1000  10,749개   6,424개
# 6              허브모음 바질트리 로즈마리 페파민트 라벤더 민트 식용허브 공기정화식물   2000   2,348개   3,037개
# 7                    허브키우기 식용 허브 화분 모종 바질 로즈마리 라벤더 민트   1000  12,886개  10,410개
# 8   허브화분 바질 루꼴라 고수 애플민트 스피아민트 라벤더 레몬밤 장미허브 초코민트 로즈...    990     827개   1,157개
# 9                              바질 생바질 스윗바질 가락시장(100g)   6000     103개     431개
# 10                             바질 생바질 스윗바질 가락시장 (1KG)  39000     261개     498개
# 11  허브 화분 로즈마리 외목대 페퍼민트 바질트리 구문초 레몬밤 애플민트 바질 장미허브 ...   9900     149개     405개
# 12    허브 모음 로즈마리 애플 페퍼 민트 마리노 라벤더 바질 스피아 월동 화분 모종 키우기   2200     185개     254개
# 13                                     바질트리 허브식물 식용식물  14000      55개      17개
# 14                               바질화분 (만원이상 배송 가능합니다)   7000      20개      56개
# 15         향기나는 허브식물 모음 (유칼립투스 애플민트 라벤더 바질트리 로즈마리 율마)   9900     418개     594개
# 16                            식용바질 허브 식물 50g 100g 생바질   4900      18개     100개
# 17          로즈마리 애플민트 바질 페퍼민트 바질트리 초코민트 토분 허브 화분 허브모음   8900      77개     247개
# 18                              몸에 좋은 허브 스위트 바질 모종 화분   9900     240개      70개
# 19                    도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000     582개     229개
# 20                      허브 키우기 스위트바질 레몬타임 파인애플민트 로즈마리   3000       3개       9개
# 21            허브 공기정화 다육 식물 소품 미니 화분 바질 로즈마리 루꼴라 스테비아   1600   3,282개     505개
# 22         율마 로즈마리 페퍼 초코 바질 장미 애플민트 레몬밤 구문초 라벤더 허브 식물    950       1개       없음
# 23  허브 화분 독일 토분 로즈마리 모히또 페퍼민트 바질트리 구문초 레몬밤 애플민트 스위...  15900       6개      19개
# 24  허브 화분 독일 토분 로즈마리 모히또 페퍼민트 바질트리 구문초 레몬밤 애플민트 스위...  15900       6개      19개
# 25                           유럽향신료 모음 후추 페페로치노 바질 파슬리   3000       없음       없음
# 26                 바질트리 향이 좋은 바질트리 허브 소품 중품 이태리토분 바구니   5000       없음       없음
# 27                              몸에 좋은 허브 스위트 바질 모종 화분   9900       없음       없음
# 28              갑조네 허브 향기나는식물 로즈마리 레몬밤 바질 허브화분 공기정화식물   2000   1,634개       없음
# 29                                    허브 모종 바질화분 식용허브   4100       6개       없음
# 30                                    스윗바질 1봉 100g 생잎   7000   3,189개   3,359개
# 31                                     바질화분2개.루꼴라화분2개  18000      82개     177개
# 32             플라워무드 허브키우기 로즈마리 스위트바질 페퍼민트 레몬밤 토분 SET  19000      13개       없음
# 33                    채소랑 바질 100g,생바질, 얼지않고 정말 신선한 바질   7500     187개     568개
# 34        [네오플라워] 허브  낱개 판매 / 애플민트 바질 레몬밤 로즈마리 라벤더 바질   1220   6,692개       없음
# 35                                     바질 100g / 200g   4000      20개       없음
# 36                                      바질 생잎 1kg 패스토  60000      11개       5개
# 37                 바질트리 향이 좋은 바질트리 허브 소품 중품 이태리토분 바구니   5000       1개       5개
# 38             허브 화분 모종 바질 레몬밤 페퍼민트 스피아민트 구문초 율마 스테비아   2000       8개       없음
# 39                      허브 생잎 16종 20g 로즈마리 애플민트 타임 바질  10050     199개     208개
# 40                                   허브 바질 다양한허브 애플민트   2120       3개       없음
# 41    식용허브모음 바질 로즈마리 애플민트 화분 페퍼민트 라벤더 유칼립투스 율마 허브 키우기  11700      33개      59개
# 42        로즈마리 바질 애플민트 스피아민트 박하 초코민트 라벤더 허브 키우기 좋은 식물  14900       9개      31개
# 43                         바질트리 식용식물 독일 토분 허브키우기 허브화분  19900       3개       6개
# 44                                바질트리 바질 허브모종 공기정화식물   8200       3개      11개
# 45             허브식물 모음 레몬밤 로즈마리 스위트바질 스피아민트 애플민트 페퍼민트   2000       8개       없음
# 46                       허브 식물 공기정화식물 다육 미니 화분 키우기 바질   1600   3,883개       없음
# 47                                  휘스트리 허브바질트리 화분 셋트  17600       3개       9개

# %%
notNull = []

checkNull = ext.notnull()

for i in range(len(checkNull)):
    if checkNull[0][i] == True:
        notNull.append(i)

# %%
weight = df.loc[notNull]

# %%
weight['무게(g)'] = ext[0]
weight
# Out:
#                                 상품명     가격     리뷰수    구매건수 무게(g)
# 2   도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000    582개    229개   100
# 9            바질 생바질 스윗바질 가락시장(100g)   6000    103개    431개   100
# 10           바질 생바질 스윗바질 가락시장 (1KG)  39000    261개    498개  1000
# 16          식용바질 허브 식물 50g 100g 생바질   4900     18개    100개    50
# 19  도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000    582개    229개   100
# 30                  스윗바질 1봉 100g 생잎   7000  3,189개  3,359개   100
# 33  채소랑 바질 100g,생바질, 얼지않고 정말 신선한 바질   7500    187개    568개   100
# 35                   바질 100g / 200g   4000     20개      없음   100
# 36                    바질 생잎 1kg 패스토  60000     11개      5개  1000
# 39    허브 생잎 16종 20g 로즈마리 애플민트 타임 바질  10050    199개    208개    20

# %%
weight['g당 가격'] = weight['가격'] / weight['무게(g)']
weight
# Out:
#                                 상품명     가격     리뷰수    구매건수 무게(g)  g당 가격
# 2   도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000    582개    229개   100     60
# 9            바질 생바질 스윗바질 가락시장(100g)   6000    103개    431개   100     60
# 10           바질 생바질 스윗바질 가락시장 (1KG)  39000    261개    498개  1000     39
# 16          식용바질 허브 식물 50g 100g 생바질   4900     18개    100개    50     98
# 19  도시농장 생 바질 100g 농업회사법인 그린(Griin)   6000    582개    229개   100     60
# 30                  스윗바질 1봉 100g 생잎   7000  3,189개  3,359개   100     70
# 33  채소랑 바질 100g,생바질, 얼지않고 정말 신선한 바질   7500    187개    568개   100     75
# 35                   바질 100g / 200g   4000     20개      없음   100     40
# 36                    바질 생잎 1kg 패스토  60000     11개      5개  1000     60
# 39    허브 생잎 16종 20g 로즈마리 애플민트 타임 바질  10050    199개    208개    20  502.5
