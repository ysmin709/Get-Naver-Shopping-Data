# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\YSM\\Downloads\\result.csv')
df
# Out:
#        Jeju   Seoul   Daegu  Jeonju  Gwangju   Sejong  Changwon     AVG
# 0   2700.00  1980.0  1980.0  1980.0  1980.00  1338.33   1980.00  1600.0
# 1   2700.00  1980.0  1980.0  1980.0  1980.00  1296.67   1980.00  1618.0
# 2   2700.00  1980.0  1980.0  1980.0  1980.00  1250.00   1980.00  1623.0
# 3   2700.00  1980.0  1980.0  1980.0  1980.00  1464.00   1980.00  1689.0
# 4   3083.33  1980.0  1980.0  1980.0  1980.00  1580.00   1980.00  1816.0
# 5   3160.00  1980.0  1980.0  1980.0  1980.00  1504.00   1980.00  1918.0
# 6   3160.00  1980.0  1980.0  1980.0  1980.00  1520.00   1980.00  1970.0
# 7   3080.00  1980.0  1980.0  2068.0  1980.00  1574.00   2068.00  1990.0
# 8   3143.33  1980.0  1980.0  2200.0  1980.00  1991.67   2126.67  2008.0
# 9   3510.00  1980.0  1980.0  2200.0  1980.00  2000.00   2053.33  1937.0
# 10  3912.00  1980.0  1980.0  2334.0  1980.00  2516.00   2200.00  1894.0
# 11  3845.00  1980.0  1980.0  1980.0  1980.00  2415.00   2200.00  1938.0
# ...

# %%
Rate = 0

# %%
Jeju = df['Jeju']
Seoul = df['Seoul']
Daegu = df['Daegu']
Jeonju = df['Jeonju']
Gwangju = df['Gwangju']
Sejong = df['Sejong']
Changwon = df['Changwon']
AVG = df['AVG']

# %%
max_Jeju = max(Jeju)
max_Seoul = max(Seoul)
max_Daegu = max(Daegu)
max_Jeonju = max(Jeonju)
max_Gwangju = max(Gwangju)
max_Sejong = max(Sejong)
max_Changwon = max(Changwon)
max_AVG = max(AVG)

# %%
Rate_max_Seoul = round((max_Jeju / max_Seoul - 1) * 100, 2)
Rate_max_Daegu = round((max_Jeju / max_Daegu - 1) * 100, 2)
Rate_max_Jeonju = round((max_Jeju / max_Jeonju - 1) * 100, 2)
Rate_max_Gwangju = round((max_Jeju / max_Gwangju - 1) * 100, 2)
Rate_max_Sejong = round((max_Jeju / max_Sejong - 1) * 100, 2)
Rate_max_Changwon = round((max_Jeju / max_Changwon - 1) * 100, 2)
Rate_max_AVG = round((max_Jeju / max_AVG - 1) * 100, 2)

# %%
Rate_list = [Rate_max_Seoul, Rate_max_Daegu, Rate_max_Jeonju, Rate_max_Gwangju, Rate_max_Sejong, Rate_max_Changwon, Rate_max_AVG]

# %%
Rate_list
# Out:
# [97.58, 97.58, 67.61, 77.82, 55.48, 77.82, 94.82]

# %%
max_df = pd.DataFrame(Rate_list, ['Seoul', 'Daegu', 'Jeonju', 'Gwangju', 'Sejong', 'Changwon', 'AVG'], ['Rate of change'])

# %%
max_df
# Out:
#           Rate of change
# Seoul              97.58
# Daegu              97.58
# Jeonju             67.61
# Gwangju            77.82
# Sejong             55.48
# Changwon           77.82
# AVG                94.82

# %%
plt.title('Max Price Compared to Jeju')
# x축 라벨 설정
plt.xlabel('Area')
# x축 라벨 설정
plt.ylabel('Rate')

plt.ylim([40, 100])
# 선 그래프(x, y)
plt.plot(max_df.index, max_df['Rate of change'])
# 막대 그래프(x, y)
plt.bar(max_df.index, max_df['Rate of change'])
# 그래프 출력
plt.show()
